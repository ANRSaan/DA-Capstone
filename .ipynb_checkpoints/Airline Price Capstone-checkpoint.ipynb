# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob

# %matplotlib inline

sns.set()

# %%
df_inflation = pd.read_csv("API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_4701153.csv", header = 2)
df_covid = pd.read_csv("owid-covid-data.csv")
df_oil = pd.read_csv("Monthly Prices-Table 1.csv", header = 4)
df_price = pd.read_csv("SeriesReport-AirlinePriceData.csv")

# %%
path = os.path.join(os.getcwd(), "airline_price_data")
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
dfs = [pd.read_csv(fp) for fp in csv_files]
# Out:
# /var/folders/3r/m5gty8797sbf_dpcyjs01g3h0000gn/T/ipykernel_639/843862321.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(fp) for fp in csv_files]
# /var/folders/3r/m5gty8797sbf_dpcyjs01g3h0000gn/T/ipykernel_639/843862321.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(fp) for fp in csv_files]
# /var/folders/3r/m5gty8797sbf_dpcyjs01g3h0000gn/T/ipykernel_639/843862321.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(fp) for fp in csv_files]
# /var/folders/3r/m5gty8797sbf_dpcyjs01g3h0000gn/T/ipykernel_639/843862321.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(fp) for fp in csv_files]

# %%
dfs
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 dfs
#
# File ~/anaconda3/envs/eda/lib/python3.10/site-packages/IPython/core/displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~/anaconda3/envs/eda/lib/python3.10/site-packages/IPython/core/displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
#     150     """
# ...

# %%
df_sample = pd.read_csv("DB1BTicket_2022_1.csv").sample(n = 10000)

# %%
df_sample
# Out:
#                ItinID  Coupons  Year  Quarter Origin  OriginAirportID  \
# 1741604  202213725791        4  2022        1    BLI            10666
# 3015671  202212259922        2  2022        1    USA            12544
# 3664015  202211280806        4  2022        1    SAN            14679
# 3332690  202211004037        2  2022        1    JFK            12478
# 344300   202211843366        4  2022        1    MSY            13495
# ...               ...      ...   ...      ...    ...              ...
# 2645568  202211388755        2  2022        1    ATL            10397
# 1438459  202211410229        2  2022        1    BDL            10529
# 2250329   20221531745        2  2022        1    MCI            13198
# 3475127   20221111336        3  2022        1    ATL            10397
# 100524   202213053371        2  2022        1    RDD            14487
#
#          OriginAirportSeqID  OriginCityMarketID OriginCountry  \
# 1741604             1066602               30666            US
# ...

# %%
df_inflation.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2013      2014      2015       2016       2017  \
# 0   NaN   NaN   NaN  ... -2.372065  0.421441  0.474764  -0.931196  -1.028282
# 1   NaN   NaN   NaN  ...  5.750981  5.370290  5.250171   6.571396   6.399343
# ...

# %%
df_oil.head()
# Out:
#   Unnamed: 0 Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# 0        NaN            ($/bbl)          ($/bbl)          ($/bbl)
# 1    1960M01               1.63             1.63             1.63
# 2    1960M02               1.63             1.63             1.63
# 3    1960M03               1.63             1.63             1.63
# 4    1960M04               1.63             1.63             1.63
#
#   Crude oil, WTI Coal, Australian ** Coal, South African ** Natural gas, US  \
# 0        ($/bbl)              ($/mt)                 ($/mt)       ($/mmbtu)
# 1              …                   …                      …            0.14
# 2              …                   …                      …            0.14
# 3              …                   …                      …            0.14
# 4              …                   …                      …            0.14
#
#   Natural gas, Europe ** Liquefied natural gas, Japan  ... Unnamed: 79  \
# ...

# %%
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_inflation.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2013      2014      2015       2016       2017  \
# 0   NaN   NaN   NaN  ... -2.372065  0.421441  0.474764  -0.931196  -1.028282
# 1   NaN   NaN   NaN  ...  5.750981  5.370290  5.250171   6.571396   6.399343
# ...

# %%
df_price.head()
# Out:
#                                                                                                        Table 1
# CPI for All Urban Consumers (CPI-U) NaN            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN     NaN
# Original Data Value                 NaN            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN     NaN
# NaN                                 NaN            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN     NaN
# Series Id:                          CUUR0000SETG01 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN     NaN
# Not Seasonally Adjusted             NaN            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN     NaN

# %%
# Out:
# array([2022])

# %%
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Out:
# array([2022])

# %%
plt.xlim(-0.03, 0.03)
sns.lineplot(data=df_ticket, x="FarePerMile", y="Quarter")
# Out:
# <AxesSubplot:xlabel='FarePerMile', ylabel='Quarter'>
